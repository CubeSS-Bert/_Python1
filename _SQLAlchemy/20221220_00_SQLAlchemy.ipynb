# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:Syntra_1408@localhost: 5432/dvdrental')

# %%
from sqlalchemy import MetaData
metadata = MetaData()

# %%
from sqlalchemy import Table, Column, Integer, Numeric, String, ForeignKey

cookies = Table('cookies', metadata,
    Column('cookie_id', Integer(), primary_key=True),
    Column('cookie_name', String(50), index=True),
    Column('cookie_recipe_url', String(255)),
    Column('cookie_sku', String(55)),
    Column('quantity', Integer()),
    Column('unit_cost', Numeric(12, 2))
)

# %%
from datetime import datetime
from sqlalchemy import DateTime

users = Table('users', metadata,
    Column('user_id', Integer(), primary_key=True),
    Column('username', String(15), nullable=False, unique=True),
    Column('email_address', String(255), nullable=False),
    Column('phone', String(20), nullable=False),
    Column('password', String(25), nullable=False),
    Column('created_on', DateTime(), default=datetime.now),
    Column('updated_on', DateTime(), default=datetime.now, onupdate=datetime.now),
    )

# %%
from sqlalchemy import ForeignKey, Boolean

orders = Table('orders', metadata,
    Column('order_id', Integer(), primary_key=True),
    Column('user_id', ForeignKey('users.user_id')),
    Column('shipped', Boolean(), default=False)
)

line_items = Table('line_items', metadata,
    Column('line_items_id', Integer(), primary_key=True),
    Column('order_id', ForeignKey('orders.order_id')),
    Column('cookie_id', ForeignKey('cookies.cookie_id')),
    Column('quantity', Integer()),
    Column('extended_cost', Numeric(12, 2))
)

# %%
metadata.create_all(engine)

# %%
ins = cookies.insert().values(
    cookie_name="chocolate chip",
    cookie_recipe_url="http://cookie",
    cookie_sku='CC01',
    quantity= "12",
    unit_cost="0.50"
)

# %%
result = engine.execute(ins)

# %%
from sqlalchemy import insert

ins = insert(cookies).values(
            cookie_name="chocolate chip",
            cookie_recipe_url="http://some.aweso.me/cookie/recipe.html",
            cookie_sku="CC01",
            quantity="12",
            unit_cost="0.50"
        )

# %%
ins = cookies.insert()
result = engine.execute(
            ins,
            cookie_name='dark chocolate chip',
            cookie_recipe_url='http://some.aweso.me/cookie/recipe_dark.html',
            cookie_sku='CC02',
            unit_cost='0.75'
            )
result.inserted_primary_key
# Out:
# (10,)

# %%
ins = cookies.insert()

inventory_list = [
        {
            'cookie_name': 'peanut butter',
            'cookie_recipe_url': 'http://some.aweso.me/cookie/peanut.html',
            'cookie_sku': 'PB01',
            'quantity': '24',
            'unit_cost': '0.25'
        },
        {
            'cookie_name': 'oatmeal raisin',
            'cookie_recipe_url': 'http://some.okay.me/cookie/raisin.html',
            'cookie_sku': 'EWW01',
            'quantity': '100',
            'unit_cost': '1.00'
        }
    ]

result = engine.execute(ins, inventory_list)

# %%
from sqlalchemy.sql import select
s = select([cookies.c.cookie_name, cookies.c.quantity])
print(s)
rp = engine.execute(s)
results = rp.fetchall()
print(results)
print(rp.keys())
# Out:
# SELECT cookies.cookie_name, cookies.quantity
# FROM cookies
# [('chocolate chip', 12), ('dark chocolate chip', None), ('peanut butter', 24), ('oatmeal raisin', 100), ('chocolate chip', 12), ('dark chocolate chip', None), ('peanut butter', 24), ('oatmeal raisin', 100), ('chocolate chip', 12), ('dark chocolate chip', None), ('peanut butter', 24), ('oatmeal raisin', 100)]
# RMKeyView(['cookie_name', 'quantity'])

# %%
s = select([cookies.c.cookie_name, cookies.c.quantity])
s = s.order_by(cookies.c.quantity)
rp = engine.execute(s)
for cookie in rp:
    print(f' {cookie.quantity} - {cookie.cookie_name} ')
# Out:
#  12 - chocolate chip
#  12 - chocolate chip
#  12 - chocolate chip
#  24 - peanut butter
#  24 - peanut butter
#  24 - peanut butter
#  100 - oatmeal raisin
#  100 - oatmeal raisin
#  100 - oatmeal raisin
#  None - dark chocolate chip
#  None - dark chocolate chip
#  None - dark chocolate chip

# %%
from sqlalchemy import desc

s = select([cookies.c.cookie_name, cookies.c.quantity])
s = s.order_by(desc(cookies.c.quantity))
rp = engine.execute(s)
for cookie in rp:
    print(f' {cookie.quantity} - {cookie.cookie_name} ')
# Out:
#  None - dark chocolate chip
#  None - dark chocolate chip
#  None - dark chocolate chip
#  100 - oatmeal raisin
#  100 - oatmeal raisin
#  100 - oatmeal raisin
#  24 - peanut butter
#  24 - peanut butter
#  24 - peanut butter
#  12 - chocolate chip
#  12 - chocolate chip
#  12 - chocolate chip

# %%
s = select([cookies.c.cookie_name, cookies.c.quantity])
s = s.order_by(desc(cookies.c.quantity))
s = s.limit(2)
rp = engine.execute(s)
print([result.cookie_name for result in rp])
# Out:
# ['dark chocolate chip', 'dark chocolate chip']

# %%
from sqlalchemy.sql import select
from sqlalchemy.sql import func

s = select((func.sum(cookies.c.quantity)))
rp = engine.execute(s)
results = rp.fetchall()
print(results)
print(results[0])
print(results[0][0])
# Out:
# [(408,)]
# (408,)
# 408

# %%
s = select((func.count(cookies.c.cookie_name)))
print(s)
rp = engine.execute(s)
record = rp.first()
print(record)
print(record.keys())
print(record.count_1)
# Out:
# SELECT count(cookies.cookie_name) AS count_1
# FROM cookies
# (12,)
# RMKeyView(['count_1'])
# 12

# %%
s = select((func.count(cookies.c.cookie_name).label('inventory_count')))
print(s)
rp = engine.execute(s)
record = rp.first()
print(record)
print(record.keys())
print(record.inventory_count)
print(type(record))
# Out:
# SELECT count(cookies.cookie_name) AS inventory_count
# FROM cookies
# (12,)
# RMKeyView(['inventory_count'])
# 12
# <class 'sqlalchemy.engine.row.LegacyRow'>

# %%
s = select((cookies)).where(cookies.c.cookie_name == 'chocolate chip')
print(s)
rp = engine.execute(s)
results = rp.fetchall()
for result in results:
    print(result)
# Out:
# SELECT cookies.cookie_id, cookies.cookie_name, cookies.cookie_recipe_url, cookies.cookie_sku, cookies.quantity, cookies.unit_cost
# FROM cookies
# WHERE cookies.cookie_name = :cookie_name_1
# (1, 'chocolate chip', 'http://cookie', 'CC01', 12, Decimal('0.50'))
# (5, 'chocolate chip', 'http://cookie', 'CC01', 12, Decimal('0.50'))
# (9, 'chocolate chip', 'http://cookie', 'CC01', 12, Decimal('0.50'))

# %%
s = select((cookies)).where(cookies.c.cookie_name.like('%chocolate´%'))
print(s)
rp = engine.execute(s)
results = rp.fetchall()
print(results)
# Out:
# SELECT cookies.cookie_id, cookies.cookie_name, cookies.cookie_recipe_url, cookies.cookie_sku, cookies.quantity, cookies.unit_cost
# FROM cookies
# WHERE cookies.cookie_name LIKE :cookie_name_1
# []

# %%
from sqlalchemy import create_engine
from sqlalchemy import MetaData

engine = create_engine('postgresql+psycopg2://postgres:Syntra_1408@localhost: 5432/dvdrental')
metadata = MetaData()

countries = Table('country', metadata,
                  Column('country_id'),
                  Column('country')
                  )

metadata.create_all(engine)


s = countries.select().order_by(countries.c.country_id)
rp = engine.execute(s)
results = rp.fetchall()
print(results)
# Out:
# [(1, 'Afghanistan'), (2, 'Algeria'), (3, 'American Samoa'), (4, 'Angola'), (5, 'Anguilla'), (6, 'Argentina'), (7, 'Armenia'), (8, 'Australia'), (9, 'Austria'), (10, 'Azerbaijan'), (11, 'Bahrain'), (12, 'Bangladesh'), (13, 'Belarus'), (14, 'Bolivia'), (15, 'Brazil'), (16, 'Brunei'), (17, 'Bulgaria'), (18, 'Cambodia'), (19, 'Cameroon'), (20, 'Canada'), (21, 'Chad'), (22, 'Chile'), (23, 'China'), (24, 'Colombia'), (25, 'Congo, The Democratic Republic of the'), (26, 'Czech Republic'), (27, 'Dominican Republic'), (28, 'Ecuador'), (29, 'Egypt'), (30, 'Estonia'), (31, 'Ethiopia'), (32, 'Faroe Islands'), (33, 'Finland'), (34, 'France'), (35, 'French Guiana'), (36, 'French Polynesia'), (37, 'Gambia'), (38, 'Germany'), (39, 'Greece'), (40, 'Greenland'), (41, 'Holy See (Vatican City State)'), (42, 'Hong Kong'), (43, 'Hungary'), (44, 'India'), (45, 'Indonesia'), (46, 'Iran'), (47, 'Iraq'), (48, 'Israel'), (49, 'Italy'), (50, 'Japan'), (51, 'Kazakstan'), (52, 'Kenya'), (53, 'Kuwait'), (54, 'Latvia'), (55, 'Liechtenstein'), (56, 'Lithuania'), (57, 'Madagascar'), (58, 'Malawi'), (59, 'Malaysia'), (60, 'Mexico'), (61, 'Moldova'), (62, 'Morocco'), (63, 'Mozambique'), (64, 'Myanmar'), (65, 'Nauru'), (66, 'Nepal'), (67, 'Netherlands'), (68, 'New Zealand'), (69, 'Nigeria'), (70, 'North Korea'), (71, 'Oman'), (72, 'Pakistan'), (73, 'Paraguay'), (74, 'Peru'), (75, 'Philippines'), (76, 'Poland'), (77, 'Puerto Rico'), (78, 'Romania'), (79, 'Runion'), (80, 'Russian Federation'), (81, 'Saint Vincent and the Grenadines'), (82, 'Saudi Arabia'), (83, 'Senegal'), (84, 'Slovakia'), (85, 'South Africa'), (86, 'South Korea'), (87, 'Spain'), (88, 'Sri Lanka'), (89, 'Sudan'), (90, 'Sweden'), (91, 'Switzerland'), (92, 'Taiwan'), (93, 'Tanzania'), (94, 'Thailand'), (95, 'Tonga'), (96, 'Tunisia'), (97, 'Turkey'), (98, 'Turkmenistan'), (99, 'Tuvalu'), (100, 'Ukraine'), (101, 'United Arab Emirates'), (102, 'United Kingdom'), (103, 'United States'), (104, 'Venezuela'), (105, 'Vietnam'), (106, 'Virgin Islands, U.S.'), (107, 'Yemen'), (108, 'Yugoslavia'), (109, 'Zambia'), (110, 'Belgium')]

# %%
from sqlalchemy import func
from sqlalchemy.sql import select


s = select((func.count(countries.c.country_id).label('aantal_landen')))
print(s)
rp = engine.execute(s)
# results = rp.fetchall()
results = rp.scalar()
print(results)
# Out:
# SELECT count(country.country_id) AS aantal_landen
# FROM country
# 110

# %%
customers = Table('customer', metadata,
                  Column('first_name')
                  )

# %%
s = select((customers.c.first_name))
print(s)
rp = engine.execute(s)
results = rp.fetchall()
print(results)
# Out:
# SELECT customer.first_name
# FROM customer
# [('Jared',), ('Mary',), ('Patricia',), ('Linda',), ('Barbara',), ('Elizabeth',), ('Jennifer',), ('Maria',), ('Susan',), ('Margaret',), ('Dorothy',), ('Lisa',), ('Nancy',), ('Karen',), ('Betty',), ('Helen',), ('Sandra',), ('Donna',), ('Carol',), ('Ruth',), ('Sharon',), ('Michelle',), ('Laura',), ('Sarah',), ('Kimberly',), ('Deborah',), ('Jessica',), ('Shirley',), ('Cynthia',), ('Angela',), ('Melissa',), ('Brenda',), ('Amy',), ('Anna',), ('Rebecca',), ('Virginia',), ('Kathleen',), ('Pamela',), ('Martha',), ('Debra',), ('Amanda',), ('Stephanie',), ('Carolyn',), ('Christine',), ('Marie',), ('Janet',), ('Catherine',), ('Frances',), ('Ann',), ('Joyce',), ('Diane',), ('Alice',), ('Julie',), ('Heather',), ('Teresa',), ('Doris',), ('Gloria',), ('Evelyn',), ('Jean',), ('Cheryl',), ('Mildred',), ('Katherine',), ('Joan',), ('Ashley',), ('Judith',), ('Rose',), ('Janice',), ('Kelly',), ('Nicole',), ('Judy',), ('Christina',), ('Kathy',), ('Theresa',), ('Beverly',), ('Denise',), ('Tammy',), ('Irene',), ('Jane',), ('Lori',), ('Rachel',), ('Marilyn',), ('Andrea',), ('Kathryn',), ('Louise',), ('Sara',), ('Anne',), ('Jacqueline',), ('Wanda',), ('Bonnie',), ('Julia',), ('Ruby',), ('Lois',), ('Tina',), ('Phyllis',), ('Norma',), ('Paula',), ('Diana',), ('Annie',), ('Lillian',), ('Emily',), ('Robin',), ('Peggy',), ('Crystal',), ('Gladys',), ('Rita',), ('Dawn',), ('Connie',), ('Florence',), ('Tracy',), ('Edna',), ('Tiffany',), ('Carmen',), ('Rosa',), ('Cindy',), ('Grace',), ('Wendy',), ('Victoria',), ('Edith',), ('Kim',), ('Sherry',), ('Sylvia',), ('Josephine',), ('Thelma',), ('Shannon',), ('Sheila',), ('Ethel',), ('Ellen',), ('Elaine',), ('Marjorie',), ('Carrie',), ('Charlotte',), ('Monica',), ('Esther',), ('Pauline',), ('Emma',), ('Juanita',), ('Anita',), ('Rhonda',), ('Hazel',), ('Amber',), ('Eva',), ('Debbie',), ('April',), ('Leslie',), ('Clara',), ('Lucille',), ('Jamie',), ('Joanne',), ('Eleanor',), ('Valerie',), ('Danielle',), ('Megan',), ('Alicia',), ('Suzanne',), ('Michele',), ('Gail',), ('Bertha',), ('Darlene',), ('Veronica',), ('Jill',), ('Erin',), ('Geraldine',), ('Lauren',), ('Cathy',), ('Joann',), ('Lorraine',), ('Lynn',), ('Sally',), ('Regina',), ('Erica',), ('Beatrice',), ('Dolores',), ('Bernice',), ('Audrey',), ('Yvonne',), ('Annette',), ('June',), ('Samantha',), ('Marion',), ('Dana',), ('Stacy',), ('Ana',), ('Renee',), ('Ida',), ('Vivian',), ('Roberta',), ('Holly',), ('Brittany',), ('Melanie',), ('Loretta',), ('Yolanda',), ('Jeanette',), ('Laurie',), ('Katie',), ('Kristen',), ('Vanessa',), ('Alma',), ('Sue',), ('Elsie',), ('Beth',), ('Jeanne',), ('Vicki',), ('Carla',), ('Tara',), ('Rosemary',), ('Eileen',), ('Terri',), ('Gertrude',), ('Lucy',), ('Tonya',), ('Ella',), ('Stacey',), ('Wilma',), ('Gina',), ('Kristin',), ('Jessie',), ('Natalie',), ('Agnes',), ('Vera',), ('Willie',), ('Charlene',), ('Bessie',), ('Delores',), ('Melinda',), ('Pearl',), ('Arlene',), ('Maureen',), ('Colleen',), ('Allison',), ('Tamara',), ('Joy',), ('Georgia',), ('Constance',), ('Lillie',), ('Claudia',), ('Jackie',), ('Marcia',), ('Tanya',), ('Nellie',), ('Minnie',), ('Marlene',), ('Heidi',), ('Glenda',), ('Lydia',), ('Viola',), ('Courtney',), ('Marian',), ('Stella',), ('Caroline',), ('Dora',), ('Jo',), ('Vickie',), ('Mattie',), ('Terry',), ('Maxine',), ('Irma',), ('Mabel',), ('Marsha',), ('Myrtle',), ('Lena',), ('Christy',), ('Deanna',), ('Patsy',), ('Hilda',), ('Gwendolyn',), ('Jennie',), ('Nora',), ('Margie',), ('Nina',), ('Cassandra',), ('Leah',), ('Penny',), ('Kay',), ('Priscilla',), ('Naomi',), ('Carole',), ('Brandy',), ('Olga',), ('Billie',), ('Dianne',), ('Tracey',), ('Leona',), ('Jenny',), ('Felicia',), ('Sonia',), ('Miriam',), ('Velma',), ('Becky',), ('Bobbie',), ('Violet',), ('Kristina',), ('Toni',), ('Misty',), ('Mae',), ('Shelly',), ('Daisy',), ('Ramona',), ('Sherri',), ('Erika',), ('James',), ('John',), ('Robert',), ('Michael',), ('William',), ('David',), ('Richard',), ('Charles',), ('Joseph',), ('Thomas',), ('Christopher',), ('Daniel',), ('Paul',) ...

# %%
# from sqlalchemy import MetaData
# metadata = MetaData()


customers = Table('customer', metadata,
                  Column('first_name'),
                  Column('last_name')
                  )

# %%
s = select((customers.c.first_name, customers.c.last_name))
print(s)
rp = engine.execute(s)
results = rp.fetchall()
print(results)
# Out:
# SELECT customer.first_name, customer.last_name
# FROM customer
# [('Jared', 'Ely'), ('Mary', 'Smith'), ('Patricia', 'Johnson'), ('Linda', 'Williams'), ('Barbara', 'Jones'), ('Elizabeth', 'Brown'), ('Jennifer', 'Davis'), ('Maria', 'Miller'), ('Susan', 'Wilson'), ('Margaret', 'Moore'), ('Dorothy', 'Taylor'), ('Lisa', 'Anderson'), ('Nancy', 'Thomas'), ('Karen', 'Jackson'), ('Betty', 'White'), ('Helen', 'Harris'), ('Sandra', 'Martin'), ('Donna', 'Thompson'), ('Carol', 'Garcia'), ('Ruth', 'Martinez'), ('Sharon', 'Robinson'), ('Michelle', 'Clark'), ('Laura', 'Rodriguez'), ('Sarah', 'Lewis'), ('Kimberly', 'Lee'), ('Deborah', 'Walker'), ('Jessica', 'Hall'), ('Shirley', 'Allen'), ('Cynthia', 'Young'), ('Angela', 'Hernandez'), ('Melissa', 'King'), ('Brenda', 'Wright'), ('Amy', 'Lopez'), ('Anna', 'Hill'), ('Rebecca', 'Scott'), ('Virginia', 'Green'), ('Kathleen', 'Adams'), ('Pamela', 'Baker'), ('Martha', 'Gonzalez'), ('Debra', 'Nelson'), ('Amanda', 'Carter'), ('Stephanie', 'Mitchell'), ('Carolyn', 'Perez'), ('Christine', 'Roberts'), ('Marie', 'Turner'), ('Janet', 'Phillips'), ('Catherine', 'Campbell'), ('Frances', 'Parker'), ('Ann', 'Evans'), ('Joyce', 'Edwards'), ('Diane', 'Collins'), ('Alice', 'Stewart'), ('Julie', 'Sanchez'), ('Heather', 'Morris'), ('Teresa', 'Rogers'), ('Doris', 'Reed'), ('Gloria', 'Cook'), ('Evelyn', 'Morgan'), ('Jean', 'Bell'), ('Cheryl', 'Murphy'), ('Mildred', 'Bailey'), ('Katherine', 'Rivera'), ('Joan', 'Cooper'), ('Ashley', 'Richardson'), ('Judith', 'Cox'), ('Rose', 'Howard'), ('Janice', 'Ward'), ('Kelly', 'Torres'), ('Nicole', 'Peterson'), ('Judy', 'Gray'), ('Christina', 'Ramirez'), ('Kathy', 'James'), ('Theresa', 'Watson'), ('Beverly', 'Brooks'), ('Denise', 'Kelly'), ('Tammy', 'Sanders'), ('Irene', 'Price'), ('Jane', 'Bennett'), ('Lori', 'Wood'), ('Rachel', 'Barnes'), ('Marilyn', 'Ross'), ('Andrea', 'Henderson'), ('Kathryn', 'Coleman'), ('Louise', 'Jenkins'), ('Sara', 'Perry'), ('Anne', 'Powell'), ('Jacqueline', 'Long'), ('Wanda', 'Patterson'), ('Bonnie', 'Hughes'), ('Julia', 'Flores'), ('Ruby', 'Washington'), ('Lois', 'Butler'), ('Tina', 'Simmons'), ('Phyllis', 'Foster'), ('Norma', 'Gonzales'), ('Paula', 'Bryant'), ('Diana', 'Alexander'), ('Annie', 'Russell'), ('Lillian', 'Griffin'), ('Emily', 'Diaz'), ('Robin', 'Hayes'), ('Peggy', 'Myers'), ('Crystal', 'Ford'), ('Gladys', 'Hamilton'), ('Rita', 'Graham'), ('Dawn', 'Sullivan'), ('Connie', 'Wallace'), ('Florence', 'Woods'), ('Tracy', 'Cole'), ('Edna', 'West'), ('Tiffany', 'Jordan'), ('Carmen', 'Owens'), ('Rosa', 'Reynolds'), ('Cindy', 'Fisher'), ('Grace', 'Ellis'), ('Wendy', 'Harrison'), ('Victoria', 'Gibson'), ('Edith', 'Mcdonald'), ('Kim', 'Cruz'), ('Sherry', 'Marshall'), ('Sylvia', 'Ortiz'), ('Josephine', 'Gomez'), ('Thelma', 'Murray'), ('Shannon', 'Freeman'), ('Sheila', 'Wells'), ('Ethel', 'Webb'), ('Ellen', 'Simpson'), ('Elaine', 'Stevens'), ('Marjorie', 'Tucker'), ('Carrie', 'Porter'), ('Charlotte', 'Hunter'), ('Monica', 'Hicks'), ('Esther', 'Crawford'), ('Pauline', 'Henry'), ('Emma', 'Boyd'), ('Juanita', 'Mason'), ('Anita', 'Morales'), ('Rhonda', 'Kennedy'), ('Hazel', 'Warren'), ('Amber', 'Dixon'), ('Eva', 'Ramos'), ('Debbie', 'Reyes'), ('April', 'Burns'), ('Leslie', 'Gordon'), ('Clara', 'Shaw'), ('Lucille', 'Holmes'), ('Jamie', 'Rice'), ('Joanne', 'Robertson'), ('Eleanor', 'Hunt'), ('Valerie', 'Black'), ('Danielle', 'Daniels'), ('Megan', 'Palmer'), ('Alicia', 'Mills'), ('Suzanne', 'Nichols'), ('Michele', 'Grant'), ('Gail', 'Knight'), ('Bertha', 'Ferguson'), ('Darlene', 'Rose'), ('Veronica', 'Stone'), ('Jill', 'Hawkins'), ('Erin', 'Dunn'), ('Geraldine', 'Perkins'), ('Lauren', 'Hudson'), ('Cathy', 'Spencer'), ('Joann', 'Gardner'), ('Lorraine', 'Stephens'), ('Lynn', 'Payne'), ('Sally', 'Pierce'), ('Regina', 'Berry'), ('Erica', 'Matthews'), ('Beatrice', 'Arnold'), ('Dolores', 'Wagner'), ('Bernice', 'Willis'), ('Audrey', 'Ray'), ('Yvonne', 'Watkins'), ('Annette', 'Olson'), ('June', 'Carroll'), ('Samantha', 'Duncan'), ('Marion', 'Snyder'), ('Dana', 'Hart'), ('Stacy', 'Cunningham'), ('Ana', 'Bradley'), ('Renee', 'Lane'), ('I ...

# %%
# from sqlalchemy import MetaData
# metadata = MetaData()


actor = Table('actor', metadata,
                  Column('first_name'),
                  Column('last_name')
                  )
# Out:
# SELECT actor.first_name, actor.last_name
# FROM actor
# [('Penelope', 'Guiness'), ('Nick', 'Wahlberg'), ('Ed', 'Chase'), ('Jennifer', 'Davis'), ('Johnny', 'Lollobrigida'), ('Bette', 'Nicholson'), ('Grace', 'Mostel'), ('Matthew', 'Johansson'), ('Joe', 'Swank'), ('Christian', 'Gable'), ('Zero', 'Cage'), ('Karl', 'Berry'), ('Uma', 'Wood'), ('Vivien', 'Bergen'), ('Cuba', 'Olivier'), ('Fred', 'Costner'), ('Helen', 'Voight'), ('Dan', 'Torn'), ('Bob', 'Fawcett'), ('Lucille', 'Tracy'), ('Kirsten', 'Paltrow'), ('Elvis', 'Marx'), ('Sandra', 'Kilmer'), ('Cameron', 'Streep'), ('Kevin', 'Bloom'), ('Rip', 'Crawford'), ('Julia', 'Mcqueen'), ('Woody', 'Hoffman'), ('Alec', 'Wayne'), ('Sandra', 'Peck'), ('Sissy', 'Sobieski'), ('Tim', 'Hackman'), ('Milla', 'Peck'), ('Audrey', 'Olivier'), ('Judy', 'Dean'), ('Burt', 'Dukakis'), ('Val', 'Bolger'), ('Tom', 'Mckellen'), ('Goldie', 'Brody'), ('Johnny', 'Cage'), ('Jodie', 'Degeneres'), ('Tom', 'Miranda'), ('Kirk', 'Jovovich'), ('Nick', 'Stallone'), ('Reese', 'Kilmer'), ('Parker', 'Goldberg'), ('Julia', 'Barrymore'), ('Frances', 'Day-Lewis'), ('Anne', 'Cronyn'), ('Natalie', 'Hopkins'), ('Gary', 'Phoenix'), ('Carmen', 'Hunt'), ('Mena', 'Temple'), ('Penelope', 'Pinkett'), ('Fay', 'Kilmer'), ('Dan', 'Harris'), ('Jude', 'Cruise'), ('Christian', 'Akroyd'), ('Dustin', 'Tautou'), ('Henry', 'Berry'), ('Christian', 'Neeson'), ('Jayne', 'Neeson'), ('Cameron', 'Wray'), ('Ray', 'Johansson'), ('Angela', 'Hudson'), ('Mary', 'Tandy'), ('Jessica', 'Bailey'), ('Rip', 'Winslet'), ('Kenneth', 'Paltrow'), ('Michelle', 'Mcconaughey'), ('Adam', 'Grant'), ('Sean', 'Williams'), ('Gary', 'Penn'), ('Milla', 'Keitel'), ('Burt', 'Posey'), ('Angelina', 'Astaire'), ('Cary', 'Mcconaughey'), ('Groucho', 'Sinatra'), ('Mae', 'Hoffman'), ('Ralph', 'Cruz'), ('Scarlett', 'Damon'), ('Woody', 'Jolie'), ('Ben', 'Willis'), ('James', 'Pitt'), ('Minnie', 'Zellweger'), ('River', 'Dean'), ('Greg', 'Chaplin'), ('Spencer', 'Peck'), ('Kenneth', 'Pesci'), ('Charlize', 'Dench'), ('Sean', 'Guiness'), ('Christopher', 'Berry'), ('Kirsten', 'Akroyd'), ('Ellen', 'Presley'), ('Kenneth', 'Torn'), ('Daryl', 'Wahlberg'), ('Gene', 'Willis'), ('Meg', 'Hawke'), ('Chris', 'Bridges'), ('Jim', 'Mostel'), ('Spencer', 'Depp'), ('Susan', 'Davis'), ('Walter', 'Torn'), ('Matthew', 'Leigh'), ('Penelope', 'Cronyn'), ('Sidney', 'Crowe'), ('Groucho', 'Dunst'), ('Gina', 'Degeneres'), ('Warren', 'Nolte'), ('Sylvester', 'Dern'), ('Susan', 'Davis'), ('Cameron', 'Zellweger'), ('Russell', 'Bacall'), ('Morgan', 'Hopkins'), ('Morgan', 'Mcdormand'), ('Harrison', 'Bale'), ('Dan', 'Streep'), ('Renee', 'Tracy'), ('Cuba', 'Allen'), ('Warren', 'Jackman'), ('Penelope', 'Monroe'), ('Liza', 'Bergman'), ('Salma', 'Nolte'), ('Julianne', 'Dench'), ('Scarlett', 'Bening'), ('Albert', 'Nolte'), ('Frances', 'Tomei'), ('Kevin', 'Garland'), ('Cate', 'Mcqueen'), ('Daryl', 'Crawford'), ('Greta', 'Keitel'), ('Jane', 'Jackman'), ('Adam', 'Hopper'), ('Richard', 'Penn'), ('Gene', 'Hopkins'), ('Rita', 'Reynolds'), ('Ed', 'Mansfield'), ('Morgan', 'Williams'), ('Lucille', 'Dee'), ('Ewan', 'Gooding'), ('Whoopi', 'Hurt'), ('Cate', 'Harris'), ('Jada', 'Ryder'), ('Angela', 'Witherspoon'), ('Kim', 'Allen'), ('Albert', 'Johansson'), ('Fay', 'Winslet'), ('Emily', 'Dee'), ('Russell', 'Temple'), ('Jayne', 'Nolte'), ('Geoffrey', 'Heston'), ('Ben', 'Harris'), ('Minnie', 'Kilmer'), ('Meryl', 'Gibson'), ('Ian', 'Tandy'), ('Fay', 'Wood'), ('Greta', 'Malden'), ('Vivien', 'Basinger'), ('Laura', 'Brody'), ('Chris', 'Depp'), ('Harvey', 'Hope'), ('Oprah', 'Kilmer'), ('Christopher', 'West'), ('Humphrey', 'Willis'), ('Al', 'Garland'), ('Nick', 'Degeneres'), ('Laurence', 'Bullock'), ('Will', 'Wilson'), ('Kenneth', 'Hoffman'), ('Mena', 'Hopper'), ('Olympia', 'Pfeiffer'), ('Groucho', 'Williams'), ('Alan', 'Dreyfuss'), ('Michael', 'Bening'), ('William', 'Hackman'), ('Jon', 'Chase'), ('Gene', 'Mckellen'), ('Lisa', 'Monroe'), ('Ed', 'Guiness'), ('Jeff', 'Silverstone'), ('Matthew', 'Carrey'), ('Debbie', 'Akroyd'), ('Russell', 'Close'), ('Humphrey', 'Garland'), ('Michael', 'Bolger'), ('Julia', ...

# %%
s = select(actor.c.first_name, actor.c.last_name).where(actor.c.first_name == 'Penelope')
print(s)
rp = engine.execute(s)
results = rp.fetchall()
print(results)
# Out:
# SELECT actor.first_name, actor.last_name
# FROM actor
# WHERE actor.first_name = :first_name_1
# [('Penelope', 'Guiness'), ('Penelope', 'Pinkett'), ('Penelope', 'Cronyn'), ('Penelope', 'Monroe')]

# %%
from sqlalchemy import MetaData
metadata = MetaData()

customers = Table('customer', metadata,
                  Column('first_name'),
                  Column('last_name'),
                  Column('email')
                  )

# %%
s = select(func.concat(customers.c.first_name, ' ', customers.c.last_name).label('volledige_naam'), customers.c.email)
print(s)


# rp = engine.execute(s)
# results = rp.fetchall()
# print(results)
for result in results:
    print(result.volledige_naam, '\t\t\t', result.email)
# Out:
# SELECT concat(customer.first_name, :concat_1, customer.last_name) AS volledige_naam, customer.email
# FROM customer
# Jared Ely 			 jared.ely@sakilacustomer.org
# Mary Smith 			 mary.smith@sakilacustomer.org
# Patricia Johnson 			 patricia.johnson@sakilacustomer.org
# Linda Williams 			 linda.williams@sakilacustomer.org
# Barbara Jones 			 barbara.jones@sakilacustomer.org
# Elizabeth Brown 			 elizabeth.brown@sakilacustomer.org
# Jennifer Davis 			 jennifer.davis@sakilacustomer.org
# Maria Miller 			 maria.miller@sakilacustomer.org
# Susan Wilson 			 susan.wilson@sakilacustomer.org
# Margaret Moore 			 margaret.moore@sakilacustomer.org
# Dorothy Taylor 			 dorothy.taylor@sakilacustomer.org
# Lisa Anderson 			 lisa.anderson@sakilacustomer.org
# Nancy Thomas 			 nancy.thomas@sakilacustomer.org
# Karen Jackson 			 karen.jackson@sakilacustomer.org
# Rene Mcalister 			 rene.mcalister@sakilacustomer.org
# Eduardo Hiatt 			 eduardo.hiatt@sakilacustomer.org
# Terrence Gunderson 			 terrence.gunderson@sakilacustomer.org
# Enrique Forsythe 			 enrique.forsythe@sakilacustomer.org
# Freddie Duggan 			 freddie.duggan@sakilacustomer.org
# Wade Delvalle 			 wade.delvalle@sakilacustomer.org
# Austin Cintron 			 austin.cintron@sakilacustomer.org

# %%
print(customers.c)
print(len(customers.c))
# Out:
# ImmutableColumnCollection(customer.first_name, customer.last_name, customer.email)
# 3

# %%
s = select((customers.c.first_name, customers.c.last_name)).order_by(customers.c.last_name)
print(s)

rp = engine.execute(s)
results = rp.fetchall()
# print(results)
for result in results:
    print(result.first_name, result.last_name)
    print(f'De naam van de klant is {result.first_name} {result.last_name}')
# Out:
# SELECT customer.first_name, customer.last_name
# FROM customer ORDER BY customer.last_name
# Rafael Abney
# De naam van de klant is Rafael Abney
# Nathaniel Adam
# De naam van de klant is Nathaniel Adam
# Kathleen Adams
# De naam van de klant is Kathleen Adams
# Diana Alexander
# De naam van de klant is Diana Alexander
# Gordon Allard
# De naam van de klant is Gordon Allard
# Shirley Allen
# De naam van de klant is Shirley Allen
# Charlene Alvarez
# De naam van de klant is Charlene Alvarez
# Lisa Anderson
# De naam van de klant is Lisa Anderson
# Jose Andrew
# De naam van de klant is Jose Andrew
# Ida Andrews
# De naam van de klant is Ida Andrews
# Oscar Aquino
# De naam van de klant is Oscar Aquino
# Harry Arce
# De naam van de klant is Harry Arce
# Jordan Archuleta
# De naam van de klant is Jordan Archuleta
# Melanie Armstrong
# De naam van de klant is Melanie Armstrong
# Beatrice Arnold
# De naam van de klant is Beatrice Arnold
# Kent Arsenault
# De naam van de klant is Kent Arsenault
# Carl Artis
# De naam van de klant is Carl Artis
# Darryl Ashcraft
# De naam van de klant is Darryl Ashcraft
# Tyrone Asher
# De naam van de klant is Tyrone Asher
# Alma Austin
# De naam van de klant is Alma Austin
# Mildred Bailey
# De naam van de klant is Mildred Bailey
# Pamela Baker
# De naam van de klant is Pamela Baker
# Martin Bales
# De naam van de klant is Martin Bales
# Everett Banda
# De naam van de klant is Everett Banda
# Jessie Banks
# De naam van de klant is Jessie Banks
# Clayton Barbee
# De naam van de klant is Clayton Barbee
# Angel Barclay
# De naam van de klant is Angel Barclay
# Nicholas Barfield
# De naam van de klant is Nicholas Barfield
# Victor Barkley
# De naam van de klant is Victor Barkley
# Rachel Barnes
# De naam van de klant is Rachel Barnes
# Carole Barnett
# De naam van de klant is Carole Barnett
# Tracey Barrett
# De naam van de klant is Tracey Barrett
# Daisy Bates
# De naam van de klant is Daisy Bates
# Edward Baugh
# De naam van de klant is Edward Baugh
# Robert Baughman
# De naam van de klant is Robert Baughman
# Jean Bell
# De naam van de klant is Jean Bell
# Chester Benner
# De naam van de klant is Chester Benner
# Jane Bennett
# De naam van de klant is Jane Bennett
# Regina Berry
# De naam van de klant is Regina Berry
# Charlie Bess
# De naam van de klant is Charlie Bess
# Miguel Betancourt
# De naam van de klant is Miguel Betancourt
# Henry Billingsley
# De naam van de klant is Henry Billingsley
# Agnes Bishop
# De naam van de klant is Agnes Bishop
# Valerie Black
# De naam van de klant is Valerie Black
# Derek Blakely
# De naam van de klant is Derek Blakely
# Mathew Bolin
# De naam van de klant is Mathew Bolin
# Don Bone
# De naam van de klant is Don Bone
# Leon Bostic
# De naam van de klant is Leon Bostic
# Bobby Boudreau
# De naam van de klant is Bobby Boudreau
# Derrick Bourque
# De naam van de klant is Derrick Bourque
# Clifford Bowens
# De naam van de klant is Clifford Bowens
# Caroline Bowman
# De naam van de klant is Caroline Bowman
# Byron Box
# De naam van de klant is Byron Box
# Emma Boyd
# De naam van de klant is Emma Boyd
# Ana Bradley
# De naam van de klant is Ana Bradley
# Ted Breaux
# De naam van de klant is Ted Breaux
# Vickie Brewer
# De naam van de klant is Vickie Brewer
# Russell Brinson
# De naam van de klant is Russell Brinson
# Beverly Brooks
# De naam van de klant is Beverly Brooks
# Chris Brothers
# De naam van de klant is Chris Brothers
# Elizabeth Brown
# De naam van de klant is Elizabeth Brown
# Guy Brownlee
# De naam van de klant is Guy Brownlee
# Paula Bryant
# De naam van de klant is Paula Bryant
# Clinton Buford
# De naam van de klant is Clinton Buford
# Wesley Bull
# De naam van de klant is Wesley Bull
# Timothy Bunn
# De naam van de klant is Timothy Bunn
# Edwin Burk
# De naam van de klant is Edwin Burk
# Lydia Burke
# De naam van de klant is Lydia Burke
# Sidney Burleson
# De naam van de klant is Sidney Burleson
# April Burns
# De naam van de klant is April Burns
# Colleen Burton
# De naam van de klant is Colleen Burton
# Leroy Bustamante
# De naam van de klant is Leroy Bustamante
# Lois Butler
# De naam van de klant is Lois Butler
# Allen Butterfield
# De naam van de klant is Allen Butterfield
# Deanna Byrd
# De naam van de klant is Deanna Byrd
# Daniel Cabral
# De naam van de klant is Daniel Cabral
# Kay Caldwell
# De naam van de klant is Kay Caldwell
# Catherine Campbell
# De naam van de klant is Catherine Campbell
# Chad Carbone
# De naam van de klant is Chad Carbone
# Terry Carlson
# De naam van de klant is Terry Carlson
# Loretta Carpenter
# De naam van de klant is Loretta Carpenter
# Eileen Carr
# De naam van de klant is Eileen Carr
# Tony Carranza
# De naam van de klant is Tony Carranza
# June Carroll
# De naam van de klant is June Carroll
# Amanda Carter
# De naam van de klant is Amanda Carter
# Tim Cary
# De naam van de klant is Tim Cary
# Alfred Casillas
# De naam van de klant is Alfred Casillas
# Gertrude Castillo
# De naam van de klant is Gertrude Castillo
# Jenny Castro
# De naam van de klant is Jenny Castro
# Philip Causey
# De naam van de klant is Philip Causey
# Kristina Chambers
# De naam van de klant is Kristina Chambers
# Vernon Chapa
# De naam van de klant is Vernon Chapa
# Tonya Chapman
# De naam van de klant is Tonya Chapman
# Kristen Chavez
# De naam van de klant is Kristen Chavez
# Mario Cheatham
# De naam van de klant is Mario Cheatham
# Pedro Chestnut
# De naam van de klant is Pedro Chestnut
# Johnnie Chisholm
# De naam van de klant is Johnnie Chisholm
# Ramon Choate
# De naam van de klant is Ramon Choate
# Nelson Christenson
# De naam van de klant is Nelson Christenson
# Fernando Churchill
# De naam van de klant is Fernando Churchill
# Austin Cintron
# De naam van de klant is Austin Cintron
# Michelle Clark
# De naam van de klant is Michelle Clark
# Adrian Clary
# De naam van de klant is Adrian Clary
# Bernard Colby
# De naam van de klant is Bernard Colby
# Tracy Cole
# De naam van de klant is Tracy Cole
# Kathryn Coleman
# De naam van de klant is Kathryn Coleman
# Tommy Collazo
# De naam van de klant is Tommy Collazo
# Diane Collins
# De naam van de klant is Diane Collins
# Gloria Cook
# De naam van de klant is Gloria Cook
# Joan Cooper
# De naam van de klant is Joan Cooper
# Allan Cornish
# De naam van de klant is Allan Cornish
# Brett Cornwell
# De naam van de klant is Brett Cornwell
# Carlos Coughlin
# De naam van de klant is Carlos Coughlin
# Judith Cox
# De naam van de klant is Judith Cox
# Gary Coy
# De naam van de klant is Gary Coy
# Bobbie Craig
# De naam van de klant is Bobbie Craig
# Esther Crawford
# De naam van de klant is Esther Crawford
# Maurice Crawley
# De naam van de klant is Maurice Crawley
# Ivan Cromwell
# De naam van de klant is Ivan Cromwell
# Albert Crouse
# De naam van de klant is Albert Crouse
# Kim Cruz
# De naam van de klant is Kim Cruz
# Theodore Culp
# De naam van de klant is Theodore Culp
# Eugene Culpepper
# De naam van de klant is Eugene Culpepper
# Stacy Cunningham
# De naam van de klant is Stacy Cunningham
# Steven Curley
# De naam van de klant is Steven Curley
# Norman Currier
# De naam van de klant is Norman Currier
# Leah Curtis
# De naam van de klant is Leah Curtis
# Danielle Daniels
# De naam van de klant is Danielle Daniels
# Patsy Davidson
# De naam van de klant is Patsy Davidson
# Jennifer Davis
# De naam van de klant is Jennifer Davis
# Courtney Day
# De naam van de klant is Courtney Day
# Marcia Dean
# De naam van de klant is Marcia Dean
# Alvin Deloach
# De naam van de klant is Alvin Deloach
# Ron Deluca
# De naam van de klant is Ron Deluca
# Wade Delvalle
# De naam van de klant is Wade Delvalle
# Herman Devore
# De naam van de klant is Herman Devore
# Emily Diaz
# De naam van de klant is Emily Diaz
# Amber Dixon
# De naam van de klant is Amber Dixon
# Marsha Douglas
# De naam van de klant is Marsha Douglas
# Sean Douglass
# De naam van de klant is Sean Douglass
# Lloyd Dowd
# De naam van de klant is Lloyd Dowd
# Freddie Duggan
# De naam van de klant is Freddie Duggan
# Samantha Duncan
# De naam van de klant is Samantha Duncan
# Erin Dunn
# De naam van de klant is Erin Dunn
# Jeff East
# De naam van de klant is Jeff East
# Ben Easter
# De naam van de klant is Ben Easter
# Leo Ebert
# De naam van de klant is Leo Ebert
# Joyce Edwards
# De naam van de klant is Joyce Edwards
# Jimmie Eggleston
# De naam van de klant is Jimmie Eggleston
# Melvin Ellington
# De naam van de klant is Melvin Ellington
# Katie Elliott
# De naam van de klant is Katie Elliott
# Grace Ellis
# De naam van de klant is Grace Ellis
# Javier Elrod
# De naam van de klant is Javier Elrod
# Jared Ely
# De naam van de klant is Jared Ely
# Kurt Emmons
# De naam van de klant is Kurt Emmons
# Travis Estep
# De naam van de klant is Travis Estep
# Ann Evans
# De naam van de klant is Ann Evans
# John Farnsworth
# De naam van de klant is John Farnsworth
# Alexander Fennell
# De naam van de klant is Alexander Fennell
# Bertha Ferguson
# De naam van de klant is Bertha Ferguson
# Melinda Fernandez
# De naam van de klant is Melinda Fernandez
# Vicki Fields
# De naam van de klant is Vicki Fields
# Cindy Fisher
# De naam van de klant is Cindy Fisher
# Myrtle Fleming
# De naam van de klant is Myrtle Fleming
# Mae Fletcher
# De naam van de klant is Mae Fletcher
# Julia Flores
# De naam van de klant is Julia Flores
# Crystal Ford
# De naam van de klant is Crystal Ford
# Micheal Forman
# De naam van de klant is Micheal Forman
# Enrique Forsythe
# De naam van de klant is Enrique Forsythe
# Raul Fortier
# De naam van de klant is Raul Fortier
# Howard Fortner
# De naam van de klant is Howard Fortner
# Phyllis Foster
# De naam van de klant is Phyllis Foster
# Jack Foust
# De naam van de klant is Jack Foust
# Jo Fowler
# De naam van de klant is Jo Fowler
# Holly Fox
# De naam van de klant is Holly Fox
# Juan Fraley
# De naam van de klant is Juan Fraley
# Joel Francisco
# De naam van de klant is Joel Francisco
# Beth Franklin
# De naam van de klant is Beth Franklin
# Glenda Frazier
# De naam van de klant is Glenda Frazier
# Shannon Freeman
# De naam van de klant is Shannon Freeman
# Claudia Fuller
# De naam van de klant is Claudia Fuller
# Gerald Fultz
# De naam van de klant is Gerald Fultz
# Felix Gaffney
# De naam van de klant is Felix Gaffney
# Randy Gaither
# De naam van de klant is Randy Gaither
# Clarence Gamez
# De naam van de klant is Clarence Gamez
# Floyd Gandy
# De naam van de klant is Floyd Gandy
# James Gannon
# De naam van de klant is James Gannon
# Carol Garcia
# De naam van de klant is Carol Garcia
# Dave Gardiner
# De naam van de klant is Dave Gardiner
# Joann Gardner
# De naam van de klant is Joann Gardner
# Nellie Garrett
# De naam van de klant is Nellie Garrett
# Pearl Garza
# De naam van de klant is Pearl Garza
# Bill Gavin
# De naam van de klant is Bill Gavin
# Ruben Geary
# De naam van de klant is Ruben Geary
# Joy George
# De naam van de klant is Joy George
# Victoria Gibson
# De naam van de klant is Victoria Gibson
# Tanya Gilbert
# De naam van de klant is Tanya Gilbert
# Dustin Gillette
# De naam van de klant is Dustin Gillette
# Joe Gilliland
# De naam van de klant is Joe Gilliland
# Dennis Gilman
# De naam van de klant is Dennis Gilman
# Josephine Gomez
# De naam van de klant is Josephine Gomez
# Norma Gonzales
# De naam van de klant is Norma Gonzales
# Martha Gonzalez
# De naam van de klant is Martha Gonzalez
# Adam Gooch
# De naam van de klant is Adam Gooch
# Kenneth Gooden
# De naam van de klant is Kenneth Gooden
# Leslie Gordon
# De naam van de klant is Leslie Gordon
# Douglas Graf
# De naam van de klant is Douglas Graf
# Rita Graham
# De naam van de klant is Rita Graham
# Michele Grant
# De naam van de klant is Michele Grant
# Brandy Graves
# De naam van de klant is Brandy Graves
# Judy Gray
# De naam van de klant is Judy Gray
# Christopher Greco
# De naam van de klant is Christopher Greco
# Virginia Green
# De naam van de klant is Virginia Green
# Jeanette Greene
# De naam van de klant is Jeanette Greene
# Sonia Gregory
# De naam van de klant is Sonia Gregory
# Alex Gresham
# De naam van de klant is Alex Gresham
# Ross Grey
# De naam van de klant is Ross Grey
# Lillian Griffin
# De naam van de klant is Lillian Griffin
# Thomas Grigsby
# De naam van de klant is Thomas Grigsby
# Terry Grissom
# De naam van de klant is Terry Grissom
# Armando Gruber
# De naam van de klant is Armando Gruber
# Harvey Guajardo
# De naam van de klant is Harvey Guajardo
# Erik Guillen
# De naam van de klant is Erik Guillen
# Terrence Gunderson
# De naam van de klant is Terrence Gunderson
# Carla Gutierrez
# De naam van de klant is Carla Gutierrez
# Ramona Hale
# De naam van de klant is Ramona Hale
# Jessica Hall
# De naam van de klant is Jessica Hall
# Gladys Hamilton
# De naam van de klant is Gladys Hamilton
# Seth Hannon
# De naam van de klant is Seth Hannon
# Delores Hansen
# De naam van de klant is Delores Hansen
# Viola Hanson
# De naam van de klant is Viola Hanson
# Gabriel Harder
# De naam van de klant is Gabriel Harder
# Bryan Hardison
# De naam van de klant is Bryan Hardison
# Brent Harkins
# De naam van de klant is Brent Harkins
# Roberta Harper
# De naam van de klant is Roberta Harper
# Helen Harris
# De naam van de klant is Helen Harris
# Wendy Harrison
# De naam van de klant is Wendy Harrison
# Dana Hart
# De naam van de klant is Dana Hart
# Arlene Harvey
# De naam van de klant is Arlene Harvey
# Corey Hauser
# De naam van de klant is Corey Hauser
# Arnold Havens
# De naam van de klant is Arnold Havens
# Jill Hawkins
# De naam van de klant is Jill Hawkins
# Lee Hawks
# De naam van de klant is Lee Hawks
# Robin Hayes
# De naam van de klant is Robin Hayes
# Shawn Heaton
# De naam van de klant is Shawn Heaton
# Andrea Henderson
# De naam van de klant is Andrea Henderson
# Alberto Henning
# De naam van de klant is Alberto Henning
# Pauline Henry
# De naam van de klant is Pauline Henry
# Angela Hernandez
# De naam van de klant is Angela Hernandez
# Nora Herrera
# De naam van de klant is Nora Herrera
# Tracy Herrmann
# De naam van de klant is Tracy Herrmann
# Claude Herzog
# De naam van de klant is Claude Herzog
# Eduardo Hiatt
# De naam van de klant is Eduardo Hiatt
# Monica Hicks
# De naam van de klant is Monica Hicks
# Marcus Hidalgo
# De naam van de klant is Marcus Hidalgo
# Anna Hill
# De naam van de klant is Anna Hill
# Zachary Hite
# De naam van de klant is Zachary Hite
# Mattie Hoffman
# De naam van de klant is Mattie Hoffman
# Mabel Holland
# De naam van de klant is Mabel Holland
# Phillip Holm
# De naam van de klant is Phillip Holm
# Lucille Holmes
# De naam van de klant is Lucille Holmes
# Toni Holt
# De naam van de klant is Toni Holt
# Hilda Hopkins
# De naam van de klant is Hilda Hopkins
# Billie Horton
# De naam van de klant is Billie Horton
# Ray Houle
# De naam van de klant is Ray Houle
# Rose Howard
# De naam van de klant is Rose Howard
# Willie Howell
# De naam van de klant is Willie Howell
# Milton Howland
# De naam van de klant is Milton Howland
# Lauren Hudson
# De naam van de klant is Lauren Hudson
# Brandon Huey
# De naam van de klant is Brandon Huey
# Bonnie Hughes
# De naam van de klant is Bonnie Hughes
# Eleanor Hunt
# De naam van de klant is Eleanor Hunt
# Charlotte Hunter
# De naam van de klant is Charlotte Hunter
# Jeremy Hurtado
# De naam van de klant is Jeremy Hurtado
# Curtis Irby
# De naam van de klant is Curtis Irby
# Frederick Isbell
# De naam van de klant is Frederick Isbell
# Danny Isom
# De naam van de klant is Danny Isom
# Karen Jackson
# De naam van de klant is Karen Jackson
# Georgia Jacobs
# De naam van de klant is Georgia Jacobs
# Kathy James
# De naam van de klant is Kathy James
# Louise Jenkins
# De naam van de klant is Louise Jenkins
# Naomi Jennings
# De naam van de klant is Naomi Jennings
# Lena Jensen
# De naam van de klant is Lena Jensen
# Olga Jimenez
# De naam van de klant is Olga Jimenez
# Patricia Johnson
# De naam van de klant is Patricia Johnson
# Kristin Johnston
# De naam van de klant is Kristin Johnston
# Barbara Jones
# De naam van de klant is Barbara Jones
# Tiffany Jordan
# De naam van de klant is Tiffany Jordan
# Jerry Jordon
# De naam van de klant is Jerry Jordon
# Joseph Joy
# De naam van de klant is Joseph Joy
# Christian Jung
# De naam van de klant is Christian Jung
# Alan Kahn
# De naam van de klant is Alan Kahn
# Elsie Kelley
# De naam van de klant is Elsie Kelley
# Denise Kelly
# De naam van de klant is Denise Kelly
# Rhonda Kennedy
# De naam van de klant is Rhonda Kennedy
# Jerome Kenyon
# De naam van de klant is Jerome Kenyon
# Lillie Kim
# De naam van de klant is Lillie Kim
# Reginald Kinder
# De naam van de klant is Reginald Kinder
# Melissa King
# De naam van de klant is Melissa King
# Gail Knight
# De naam van de klant is Gail Knight
# Kelly Knott
# De naam van de klant is Kelly Knott
# Charles Kowalski
# De naam van de klant is Charles Kowalski
# Lester Kraus
# De naam van de klant is Lester Kraus
# Herbert Kruger
# De naam van de klant is Herbert Kruger
# Misty Lambert
# De naam van de klant is Misty Lambert
# Jacob Lance
# De naam van de klant is Jacob Lance
# Renee Lane
# De naam van de klant is Renee Lane
# Heidi Larson
# De naam van de klant is Heidi Larson
# Daryl Larue
# De naam van de klant is Daryl Larue
# Laurie Lawrence
# De naam van de klant is Laurie Lawrence
# Jeanne Lawson
# De naam van de klant is Jeanne Lawson
# Lawrence Lawton
# De naam van de klant is Lawrence Lawton
# Kimberly Lee
# De naam van de klant is Kimberly Lee
# Louis Leone
# De naam van de klant is Louis Leone
# Sarah Lewis
# De naam van de klant is Sarah Lewis
# George Linton
# De naam van de klant is George Linton
# Maureen Little
# De naam van de klant is Maureen Little
# Dwight Lombardi
# De naam van de klant is Dwight Lombardi
# Jacqueline Long
# De naam van de klant is Jacqueline Long
# Amy Lopez
# De naam van de klant is Amy Lopez
# Barry Lovelace
# De naam van de klant is Barry Lovelace
# Priscilla Lowe
# De naam van de klant is Priscilla Lowe
# Velma Lucas
# De naam van de klant is Velma Lucas
# Willard Lumpkin
# De naam van de klant is Willard Lumpkin
# Lewis Lyman
# De naam van de klant is Lewis Lyman
# Jackie Lynch
# De naam van de klant is Jackie Lynch
# Steve Mackenzie
# De naam van de klant is Steve Mackenzie
# Ralph Madrigal
# De naam van de klant is Ralph Madrigal
# Matthew Mahan
# De naam van de klant is Matthew Mahan
# Donald Mahon
# De naam van de klant is Donald Mahon
# Clifton Malcolm
# De naam van de klant is Clifton Malcolm
# Joshua Mark
# De naam van de klant is Joshua Mark
# Willie Markham
# De naam van de klant is Willie Markham
# Samuel Marlow
# De naam van de klant is Samuel Marlow
# Sherry Marshall
# De naam van de klant is Sherry Marshall
# Calvin Martel
# De naam van de klant is Calvin Martel
# Sandra Martin
# De naam van de klant is Sandra Martin
# Ruth Martinez
# De naam van de klant is Ruth Martinez
# Harold Martino
# De naam van de klant is Harold Martino
# Juanita Mason
# De naam van de klant is Juanita Mason
# Erica Matthews
# De naam van de klant is Erica Matthews
# Rick Mattox
# De naam van de klant is Rick Mattox
# Gregory Mauldin
# De naam van de klant is Gregory Mauldin
# Gwendolyn May
# De naam van de klant is Gwendolyn May
# Alfredo Mcadams
# De naam van de klant is Alfredo Mcadams
# Rene Mcalister
# De naam van de klant is Rene Mcalister
# Morris Mccarter
# De naam van de klant is Morris Mccarter
# Jesus Mccartney
# De naam van de klant is Jesus Mccartney
# Vera Mccoy
# De naam van de klant is Vera Mccoy
# Richard Mccrary
# De naam van de klant is Richard Mccrary
# Brad Mccurdy
# De naam van de klant is Brad Mccurdy
# Edith Mcdonald
# De naam van de klant is Edith Mcdonald
# Sam Mcduffie
# De naam van de klant is Sam Mcduffie
# Miriam Mckinney
# De naam van de klant is Miriam Mckinney
# Raymond Mcwhorter
# De naam van de klant is Raymond Mcwhorter
# Ricardo Meador
# De naam van de klant is Ricardo Meador
# Dora Medina
# De naam van de klant is Dora Medina
# Cory Meehan
# De naam van de klant is Cory Meehan
# Antonio Meek
# De naam van de klant is Antonio Meek
# Casey Mena
# De naam van de klant is Casey Mena
# Peter Menard
# De naam van de klant is Peter Menard
# Marian Mendoza
# De naam van de klant is Marian Mendoza
# Natalie Meyer
# De naam van de klant is Natalie Meyer
# Jessie Milam
# De naam van de klant is Jessie Milam
# Becky Miles
# De naam van de klant is Becky Miles
# Shane Millard
# De naam van de klant is Shane Millard
# Maria Miller
# De naam van de klant is Maria Miller
# Alicia Mills
# De naam van de klant is Alicia Mills
# Tom Milner
# De naam van de klant is Tom Milner
# Stephanie Mitchell
# De naam van de klant is Stephanie Mitchell
# Rodney Moeller
# De naam van de klant is Rodney Moeller
# Stacey Montgomery
# De naam van de klant is Stacey Montgomery
# Margaret Moore
# De naam van de klant is Margaret Moore
# Anita Morales
# De naam van de klant is Anita Morales
# Stella Moreno
# De naam van de klant is Stella Moreno
# Evelyn Morgan
# De naam van de klant is Evelyn Morgan
# Craig Morrell
# De naam van de klant is Craig Morrell
# Heather Morris
# De naam van de klant is Heather Morris
# Bessie Morrison
# De naam van de klant is Bessie Morrison
# Jason Morrissey
# De naam van de klant is Jason Morrissey
# Bradley Motley
# De naam van de klant is Bradley Motley
# Cheryl Murphy
# De naam van de klant is Cheryl Murphy
# Thelma Murray
# De naam van de klant is Thelma Murray
# Manuel Murrell
# De naam van de klant is Manuel Murrell
# Peggy Myers
# De naam van de klant is Peggy Myers
# Penny Neal
# De naam van de klant is Penny Neal
# Debra Nelson
# De naam van de klant is Debra Nelson
# Jaime Nettles
# De naam van de klant is Jaime Nettles
# Randall Neumann
# De naam van de klant is Randall Neumann
# Patrick Newsom
# De naam van de klant is Patrick Newsom
# Justin Ngo
# De naam van de klant is Justin Ngo
# Tamara Nguyen
# De naam van de klant is Tamara Nguyen
# Suzanne Nichols
# De naam van de klant is Suzanne Nichols
# Elmer Noe
# De naam van de klant is Elmer Noe
# Julio Noland
# De naam van de klant is Julio Noland
# Cody Nolen
# De naam van de klant is Cody Nolen
# Leona Obrien
# De naam van de klant is Leona Obrien
# Marion Ocampo
# De naam van de klant is Marion Ocampo
# Isaac Oglesby
# De naam van de klant is Isaac Oglesby
# Jorge Olivares
# De naam van de klant is Jorge Olivares
# Ella Oliver
# De naam van de klant is Ella Oliver
# Annette Olson
# De naam van de klant is Annette Olson
# Dwayne Olvera
# De naam van de klant is Dwayne Olvera
# Sylvia Ortiz
# De naam van de klant is Sylvia Ortiz
# Marc Outlaw
# De naam van de klant is Marc Outlaw
# Carmen Owens
# De naam van de klant is Carmen Owens
# Dan Paine
# De naam van de klant is Dan Paine
# Megan Palmer
# De naam van de klant is Megan Palmer
# Frances Parker
# De naam van de klant is Frances Parker
# Wanda Patterson
# De naam van de klant is Wanda Patterson
# Lynn Payne
# De naam van de klant is Lynn Payne
# Irma Pearson
# De naam van de klant is Irma Pearson
# Lance Pemberton
# De naam van de klant is Lance Pemberton
# Erika Pena
# De naam van de klant is Erika Pena
# Carolyn Perez
# De naam van de klant is Carolyn Perez
# Geraldine Perkins
# De naam van de klant is Geraldine Perkins
# Sara Perry
# De naam van de klant is Sara Perry
# Walter Perryman
# De naam van de klant is Walter Perryman
# Sue Peters
# De naam van de klant is Sue Peters
# Nicole Peterson
# De naam van de klant is Nicole Peterson
# Bob Pfeiffer
# De naam van de klant is Bob Pfeiffer
# Janet Phillips
# De naam van de klant is Janet Phillips
# Sally Pierce
# De naam van de klant is Sally Pierce
# Jeffery Pinson
# De naam van de klant is Jeffery Pinson
# Max Pitt
# De naam van de klant is Max Pitt
# Hector Poindexter
# De naam van de klant is Hector Poindexter
# Carrie Porter
# De naam van de klant is Carrie Porter
# Billy Poulin
# De naam van de klant is Billy Poulin
# Anne Powell
# De naam van de klant is Anne Powell
# Darrell Power
# De naam van de klant is Darrell Power
# Ken Prewitt
# De naam van de klant is Ken Prewitt
# Irene Price
# De naam van de klant is Irene Price
# Glenn Pullen
# De naam van de klant is Glenn Pullen
# Andrew Purdy
# De naam van de klant is Andrew Purdy
# Stephen Qualls
# De naam van de klant is Stephen Qualls
# Troy Quigley
# De naam van de klant is Troy Quigley
# Roger Quintanilla
# De naam van de klant is Roger Quintanilla
# Vincent Ralston
# De naam van de klant is Vincent Ralston
# Christina Ramirez
# De naam van de klant is Christina Ramirez
# Eva Ramos
# De naam van de klant is Eva Ramos
# Andre Rapp
# De naam van de klant is Andre Rapp
# Dale Ratcliff
# De naam van de klant is Dale Ratcliff
# Audrey Ray
# De naam van de klant is Audrey Ray
# Jim Rea
# De naam van de klant is Jim Rea
# Doris Reed
# De naam van de klant is Doris Reed
# Constance Reid
# De naam van de klant is Constance Reid
# Neil Renner
# De naam van de klant is Neil Renner
# Debbie Reyes
# De naam van de klant is Debbie Reyes
# Rosa Reynolds
# De naam van de klant is Rosa Reynolds
# Edgar Rhoads
# De naam van de klant is Edgar Rhoads
# Sherri Rhodes
# De naam van de klant is Sherri Rhodes
# Jamie Rice
# De naam van de klant is Jamie Rice
# Wilma Richards
# De naam van de klant is Wilma Richards
# Ashley Richardson
# De naam van de klant is Ashley Richardson
# Ronnie Ricketts
# De naam van de klant is Ronnie Ricketts
# Keith Rico
# De naam van de klant is Keith Rico
# Brittany Riley
# De naam van de klant is Brittany Riley
# Mark Rinehart
# De naam van de klant is Mark Rinehart
# Katherine Rivera
# De naam van de klant is Katherine Rivera
# Jay Robb
# De naam van de klant is Jay Robb
# Eric Robert
# De naam van de klant is Eric Robert
# Christine Roberts
# De naam van de klant is Christine Roberts
# Joanne Robertson
# De naam van de klant is Joanne Robertson
# Greg Robins
# De naam van de klant is Greg Robins
# Sharon Robinson
# De naam van de klant is Sharon Robinson
# Laura Rodriguez
# De naam van de klant is Laura Rodriguez
# Violet Rodriquez
# De naam van de klant is Violet Rodriquez
# Teresa Rogers
# De naam van de klant is Teresa Rogers
# Minnie Romero
# De naam van de klant is Minnie Romero
# Darlene Rose
# De naam van de klant is Darlene Rose
# Marilyn Ross
# De naam van de klant is Marilyn Ross
# Terrance Roush
# De naam van de klant is Terrance Roush
# David Royal
# De naam van de klant is David Royal
# Vivian Ruiz
# De naam van de klant is Vivian Ruiz
# Nathan Runyon
# De naam van de klant is Nathan Runyon
# Annie Russell
# De naam van de klant is Annie Russell
# Tara Ryan
# De naam van de klant is Tara Ryan
# Ryan Salisbury
# De naam van de klant is Ryan Salisbury
# Gene Sanborn
# De naam van de klant is Gene Sanborn
# Julie Sanchez
# De naam van de klant is Julie Sanchez
# Tammy Sanders
# De naam van de klant is Tammy Sanders
# William Satterfield
# De naam van de klant is William Satterfield
# Dean Sauer
# De naam van de klant is Dean Sauer
# Jonathan Scarborough
# De naam van de klant is Jonathan Scarborough
# Jesse Schilling
# De naam van de klant is Jesse Schilling
# Rosemary Schmidt
# De naam van de klant is Rosemary Schmidt
# Leonard Schofield
# De naam van de klant is Leonard Schofield
# Jimmy Schrader
# De naam van de klant is Jimmy Schrader
# Kevin Schuler
# De naam van de klant is Kevin Schuler
# Anthony Schwab
# De naam van de klant is Anthony Schwab
# Bruce Schwarz
# De naam van de klant is Bruce Schwarz
# Rebecca Scott
# De naam van de klant is Rebecca Scott
# Stanley Scroggins
# De naam van de klant is Stanley Scroggins
# Karl Seal
# De naam van de klant is Karl Seal
# Aaron Selby
# De naam van de klant is Aaron Selby
# Leslie Seward
# De naam van de klant is Leslie Seward
# Earl Shanks
# De naam van de klant is Earl Shanks
# Clara Shaw
# De naam van de klant is Clara Shaw
# Ricky Shelby
# De naam van de klant is Ricky Shelby
# Scott Shelley
# De naam van de klant is Scott Shelley
# Dianne Shelton
# De naam van de klant is Dianne Shelton
# Warren Sherrod
# De naam van de klant is Warren Sherrod
# Francis Sikes
# De naam van de klant is Francis Sikes
# Maxine Silva
# De naam van de klant is Maxine Silva
# Michael Silverman
# De naam van de klant is Michael Silverman
# Tina Simmons
# De naam van de klant is Tina Simmons
# Arthur Simpkins
# De naam van de klant is Arthur Simpkins
# Ellen Simpson
# De naam van de klant is Ellen Simpson
# Vanessa Sims
# De naam van de klant is Vanessa Sims
# Francisco Skidmore
# De naam van de klant is Francisco Skidmore
# Gilbert Sledge
# De naam van de klant is Gilbert Sledge
# Wallace Slone
# De naam van de klant is Wallace Slone
# Mary Smith
# De naam van de klant is Mary Smith
# Marion Snyder
# De naam van de klant is Marion Snyder
# Nina Soto
# De naam van de klant is Nina Soto
# Roland South
# De naam van de klant is Roland South
# Jeffrey Spear
# De naam van de klant is Jeffrey Spear
# Cathy Spencer
# De naam van de klant is Cathy Spencer
# Kyle Spurlock
# De naam van de klant is Kyle Spurlock
# Sergio Stanfield
# De naam van de klant is Sergio Stanfield
# Allison Stanley
# De naam van de klant is Allison Stanley
# Kirk Stclair
# De naam van de klant is Kirk Stclair
# Lorraine Stephens
# De naam van de klant is Lorraine Stephens
# Ernest Stepp
# De naam van de klant is Ernest Stepp
# Elaine Stevens
# De naam van de klant is Elaine Stevens
# Alice Stewart
# De naam van de klant is Alice Stewart
# Ian Still
# De naam van de klant is Ian Still
# Veronica Stone
# De naam van de klant is Veronica Stone
# Dawn Sullivan
# De naam van de klant is Dawn Sullivan
# Felicia Sutton
# De naam van de klant is Felicia Sutton
# Perry Swafford
# De naam van de klant is Perry Swafford
# Glen Talbert
# De naam van de klant is Glen Talbert
# Todd Tan
# De naam van de klant is Todd Tan
# Dorothy Taylor
# De naam van de klant is Dorothy Taylor
# Salvador Teel
# De naam van de klant is Salvador Teel
# Jennie Terry
# De naam van de klant is Jennie Terry
# Nancy Thomas
# De naam van de klant is Nancy Thomas
# Donna Thompson
# De naam van de klant is Donna Thompson
# Marshall Thorn
# De naam van de klant is Marshall Thorn
# Larry Thrasher
# De naam van de klant is Larry Thrasher
# Lonnie Tirado
# De naam van de klant is Lonnie Tirado
# Clyde Tobias
# De naam van de klant is Clyde Tobias
# Eddie Tomlin
# De naam van de klant is Eddie Tomlin
# Kelly Torres
# De naam van de klant is Kelly Torres
# Paul Trout
# De naam van de klant is Paul Trout
# Franklin Troutman
# De naam van de klant is Franklin Troutman
# Wayne Truong
# De naam van de klant is Wayne Truong
# Duane Tubbs
# De naam van de klant is Duane Tubbs
# Marjorie Tucker
# De naam van de klant is Marjorie Tucker
# Marie Turner
# De naam van de klant is Marie Turner
# Johnny Turpin
# De naam van de klant is Johnny Turpin
# Andy Vanhorn
# De naam van de klant is Andy Vanhorn
# Christy Vargas
# De naam van de klant is Christy Vargas
# Benjamin Varney
# De naam van de klant is Benjamin Varney
# Terri Vasquez
# De naam van de klant is Terri Vasquez
# Julian Vest
# De naam van de klant is Julian Vest
# Cecil Vines
# De naam van de klant is Cecil Vines
# Roberto Vu
# De naam van de klant is Roberto Vu
# Margie Wade
# De naam van de klant is Margie Wade
# Frank Waggoner
# De naam van de klant is Frank Waggoner
# Dolores Wagner
# De naam van de klant is Dolores Wagner
# Hugh Waldrop
# De naam van de klant is Hugh Waldrop
# Deborah Walker
# De naam van de klant is Deborah Walker
# Connie Wallace
# De naam van de klant is Connie Wallace
# Cassandra Walters
# De naam van de klant is Cassandra Walters
# Janice Ward
# De naam van de klant is Janice Ward
# Hazel Warren
# De naam van de klant is Hazel Warren
# Ruby Washington
# De naam van de klant is Ruby Washington
# Yvonne Watkins
# De naam van de klant is Yvonne Watkins
# Theresa Watson
# De naam van de klant is Theresa Watson
# Shelly Watts
# De naam van de klant is Shelly Watts
# Jamie Waugh
# De naam van de klant is Jamie Waugh
# Mike Way
# De naam van de klant is Mike Way
# Yolanda Weaver
# De naam van de klant is Yolanda Weaver
# Ethel Webb
# De naam van de klant is Ethel Webb
# Ronald Weiner
# De naam van de klant is Ronald Weiner
# Marlene Welch
# De naam van de klant is Marlene Welch
# Sheila Wells
# De naam van de klant is Sheila Wells
# Edna West
# De naam van de klant is Edna West
# Mitchell Westmoreland
# De naam van de klant is Mitchell Westmoreland
# Fred Wheat
# De naam van de klant is Fred Wheat
# Lucy Wheeler
# De naam van de klant is Lucy Wheeler
# Betty White
# De naam van de klant is Betty White
# Roy Whiting
# De naam van de klant is Roy Whiting
# Jon Wiles
# De naam van de klant is Jon Wiles
# Linda Williams
# De naam van de klant is Linda Williams
# Gina Williamson
# De naam van de klant is Gina Williamson
# Bernice Willis
# De naam van de klant is Bernice Willis
# Susan Wilson
# De naam van de klant is Susan Wilson
# Darren Windham
# De naam van de klant is Darren Windham
# Virgil Wofford
# De naam van de klant is Virgil Wofford
# Lori Wood
# De naam van de klant is Lori Wood
# Florence Woods
# De naam van de klant is Florence Woods
# Tyler Wren
# De naam van de klant is Tyler Wren
# Brenda Wright
# De naam van de klant is Brenda Wright
# Brian Wyman
# De naam van de klant is Brian Wyman
# Luis Yanez
# De naam van de klant is Luis Yanez
# Marvin Yee
# De naam van de klant is Marvin Yee
# Cynthia Young
# De naam van de klant is Cynthia Young

# %%
from sqlalchemy import desc

s = select(customers.c.first_name, customers.c.last_name).where(customers.c.last_name.like('L%')).order_by(desc(customers.c.first_name))
print(s)
# Out:
# SELECT customer.first_name, customer.last_name
# FROM customer
# WHERE customer.last_name LIKE :last_name_1 ORDER BY customer.first_name DESC
